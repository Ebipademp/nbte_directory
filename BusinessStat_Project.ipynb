# %% [markdown]
# <a href="https://colab.research.google.com/github/Ebipademp/nbte_directory/blob/main/BusinessStat_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Define Problem Statement and Objectives

# %% [markdown]
# ## Import all the necessary libraries

# %%
import numpy as np
import pandas as pd
import scipy.stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Reading the Data into a DataFrame

# %%
st="/content/drive/MyDrive/Business_StatisticsProject/abtest.csv"
st = pd.read_csv(st)

# %% [markdown]
# ## Explore the dataset and extract insights using Exploratory Data Analysis
#
# - Data Overview
#   - Viewing the first and last few rows of the dataset
#   - Checking the shape of the dataset
#   - Getting the statistical summary for the variables
# - Check for missing values
# - Check for duplicates

# %%
st.head()
# Out:
#    user_id      group landing_page  time_spent_on_the_page converted  \
# 0   546592    control          old                    3.48        no
# 1   546468  treatment          new                    7.13       yes
# 2   546462  treatment          new                    4.40        no
# 3   546567    control          old                    3.02        no
# 4   546459  treatment          new                    4.75       yes
#
#   language_preferred
# 0            Spanish
# 1            English
# 2            Spanish
# 3             French
# 4            Spanish

# %%
st.tail()
# Out:
#     user_id      group landing_page  time_spent_on_the_page converted  \
# 95   546446  treatment          new                    5.15        no
# 96   546544    control          old                    6.52       yes
# 97   546472  treatment          new                    7.07       yes
# 98   546481  treatment          new                    6.20       yes
# 99   546483  treatment          new                    5.86       yes
#
#    language_preferred
# 95            Spanish
# 96            English
# 97            Spanish
# 98            Spanish
# 99            English

# %%
st.shape
# Out:
# (100, 6)

# %%
st.describe()
# Out:
#              user_id  time_spent_on_the_page
# count     100.000000              100.000000
# mean   546517.000000                5.377800
# std        52.295779                2.378166
# min    546443.000000                0.190000
# 25%    546467.750000                3.880000
# 50%    546492.500000                5.415000
# 75%    546567.250000                7.022500
# max    546592.000000               10.710000

# %%
st.describe().T
# Out:
#                         count         mean        std        min        25%  \
# user_id                 100.0  546517.0000  52.295779  546443.00  546467.75
# time_spent_on_the_page  100.0       5.3778   2.378166       0.19       3.88
#
#                                50%          75%        max
# user_id                 546492.500  546567.2500  546592.00
# time_spent_on_the_page       5.415       7.0225      10.71

# %%
st.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   user_id                 100 non-null    int64
#  1   group                   100 non-null    object
#  2   landing_page            100 non-null    object
#  3   time_spent_on_the_page  100 non-null    float64
#  4   converted               100 non-null    object
#  5   language_preferred      100 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
st.isnull().sum()
# Out:
# user_id                   0
# group                     0
# landing_page              0
# time_spent_on_the_page    0
# converted                 0
# language_preferred        0
# dtype: int64

# %% [markdown]
# # Observation:
#
# There are no missing values

# %%
st.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #Observation
#
# No duplicates in the dataset

# %%
st.nunique()
# Out:
# user_id                   100
# group                       2
# landing_page                2
# time_spent_on_the_page     94
# converted                   2
# language_preferred          3
# dtype: int64

# %% [markdown]
# ### Univariate Analysis

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=st, x='user_id');

# %% [markdown]
# Observation

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=st, x='time_spent_on_the_page', kde=True);

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=st, x='language_preferred');

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.pairplot(st)

# %%
sns.relplot(y='user_id', x='time_spent_on_the_page', hue='converted', data=st)

# %%
sns.relplot(y='user_id', x='time_spent_on_the_page', hue='language_preferred', data=st)

# %%
sns.relplot(y='user_id', x='time_spent_on_the_page', hue='landing_page', data=st)

# %%
sns.relplot(y='user_id', x='time_spent_on_the_page', hue='group', data=st)

# %%
gp=st.group.unique().tolist()
st.group = pd.Categorical(st.group, ordered=True, categorises = gp)
plt.lineplot(data=st, x="group", y="time_spent_on_the_page", ci=False, color="red", estimator='sue')
plt.ylabel('Time_spent_on_the_page')
plt.xlabel('group')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-8a2946d90386> in <cell line: 2>()
#       1 gp=st.group.unique().tolist()
# ----> 2 st.group = pd.Categorical(st.group, ordered=True, categorises = gp)
#       3 plt.lineplot(data=st, x="group", y="time_spent_on_the_page", ci=False, color="red", estimator='sue')
#       4 plt.ylabel('Time_spent_on_the_page')
#       5 plt.xlabel('group')
#
# TypeError: Categorical.__init__() got an unexpected keyword argument 'categorises'

# %% [markdown]
# Observation

# %% [markdown]
# ## 1. Do the users spend more time on the new landing page than the existing landing page?
#
# ### Perform Visual Analysis

# %% [markdown]
# Observation

# %% [markdown]
# ### Step 1: Define the null and alternate hypotheses
#
# ### Step 2: Select Appropriate test
#
# ### Step 3: Decide the significance level
#
# ### Step 4: Collect and prepare data

# %% [markdown]
# ### Step 5: Calculate the p-value

# %% [markdown]
# ### Step 6: Compare the p-value with $\alpha$

# %% [markdown]
# ### Step 7:  Draw inference

# %% [markdown]
# ## 2. Is the conversion rate (the proportion of users who visit the landing page and get converted) for the new page greater than the conversion rate for the old page?

# %% [markdown]
# ## 3. Is the conversion and preferred language are independent or related?

# %% [markdown]
# ## 4. Is the time spent on the new page same for the different language users?

# %% [markdown]
# ## Conclusion and Business Recommendations
